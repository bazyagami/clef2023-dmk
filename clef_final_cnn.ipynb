# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
train_gan_dir = r'D:\Clef\dataset\generated\generated'
train_used_dir = r'D:\Clef\dataset\not_used\not_used'
train_unused_dir = r'D:\Clef\dataset\used\used'
test_gan_dir = r'D:\Clef\dataset\test_1\generated_1'
test_real_dir = r'D:\Clef\dataset\test_1\real_unknown_1'

# %%
def load_image(path):
    img = load_img(path, target_size=(64, 64))
    img = img_to_array(img)
    img = img / 255.0
    return img

# %%
def load_data():
    train_gan_images = [load_image(os.path.join(train_gan_dir, filename)) for filename in os.listdir(train_gan_dir)]
    train_used_images = [load_image(os.path.join(train_used_dir, filename)) for filename in os.listdir(train_used_dir)]
    train_unused_images = [load_image(os.path.join(train_unused_dir, filename)) for filename in os.listdir(train_unused_dir)]
    train_images = np.concatenate((train_used_images, train_unused_images))
    train_labels = np.concatenate((np.ones(len(train_used_images)), np.zeros(len(train_unused_images))))
    
    test_gan_images = [load_image(os.path.join(test_gan_dir, filename)) for filename in os.listdir(test_gan_dir)]
    test_real_images = [load_image(os.path.join(test_real_dir, filename)) for filename in os.listdir(test_real_dir)]
    
    train_images = np.array(train_images).reshape(-1, 64, 64, 3)
    test_gan_images = np.array(test_gan_images).reshape(-1, 64, 64, 3)
    test_real_images = np.array(test_real_images).reshape(-1, 64, 64, 3)
    
    return train_images, train_labels, test_gan_images, test_real_images
    
train_images, train_labels, test_gan_images, test_real_images = load_data()

# %%
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(64,64,3)),
    MaxPooling2D((2,2)),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D((2,2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_images, train_labels, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 10/10 [==============================] - 0s 45ms/step - loss: 0.6494 - accuracy: 0.6875
# Epoch 2/10
# 10/10 [==============================] - 0s 48ms/step - loss: 0.6092 - accuracy: 0.7000
# Epoch 3/10
# 10/10 [==============================] - 0s 47ms/step - loss: 0.5814 - accuracy: 0.6687
# Epoch 4/10
# 10/10 [==============================] - 0s 48ms/step - loss: 0.5024 - accuracy: 0.7625
# Epoch 5/10
# 10/10 [==============================] - 0s 48ms/step - loss: 0.3478 - accuracy: 0.9125
# Epoch 6/10
# 10/10 [==============================] - 0s 49ms/step - loss: 0.2297 - accuracy: 0.9375
# Epoch 7/10
# 10/10 [==============================] - 0s 47ms/step - loss: 0.1432 - accuracy: 0.9688
# Epoch 8/10
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0947 - accuracy: 0.9875
# Epoch 9/10
# 10/10 [==============================] - 0s 49ms/step - loss: 0.0707 - accuracy: 0.9875
# Epoch 10/10
# 10/10 [==============================] - 0s 48ms/step - loss: 0.0341 - accuracy: 1.0000

# %%
test_real_predictions = model.predict(test_real_images)


test_gan_predictions = model.predict(test_gan_images)


threshold = 0.5
test_real_predictions = (test_real_predictions > threshold).astype(int)
test_gan_predictions = (test_gan_predictions > threshold).astype(int)


for i in range(len(test_real_predictions)):
    if test_gan_predictions[i] == 1:
        ##print(f"{i+1}th test_real_image was used to generate the gan_images")
        figure_id = os.path.splitext(os.path.basename(os.path.join(test_real_dir, os.listdir(test_real_dir)[i])))[0]
        print(figure_id,', 1')
        
    else:
        ##print(f"{i+1}th test_real_image was not used to generate the gan_images")
        figure_id = os.path.splitext(os.path.basename(os.path.join(test_real_dir, os.listdir(test_real_dir)[i])))[0]
        print(figure_id,', 0')
# Out:
# 7/7 [==============================] - 0s 17ms/step
# 313/313 [==============================] - 6s 18ms/step
# real_unknown_0001 , 1
# real_unknown_0002 , 0
# real_unknown_0003 , 0
# real_unknown_0004 , 1
# real_unknown_0005 , 1
# real_unknown_0006 , 1
# real_unknown_0007 , 0
# real_unknown_0008 , 0
# real_unknown_0009 , 1
# real_unknown_0010 , 0
# real_unknown_0011 , 0
# real_unknown_0012 , 1
# real_unknown_0013 , 1
# real_unknown_0014 , 0
# real_unknown_0015 , 1
# real_unknown_0016 , 0
# real_unknown_0017 , 1
# real_unknown_0018 , 1
# real_unknown_0019 , 0
# real_unknown_0020 , 0
# real_unknown_0021 , 0
# real_unknown_0022 , 0
# real_unknown_0023 , 0
# real_unknown_0024 , 1
# real_unknown_0025 , 0
# real_unknown_0026 , 0
# real_unknown_0027 , 0
# real_unknown_0028 , 0
# real_unknown_0029 , 0
# real_unknown_0030 , 0
# real_unknown_0031 , 0
# real_unknown_0032 , 1
# real_unknown_0033 , 0
# real_unknown_0034 , 1
# real_unknown_0035 , 1
# real_unknown_0036 , 0
# real_unknown_0037 , 0
# real_unknown_0038 , 1
# real_unknown_0039 , 1
# real_unknown_0040 , 0
# real_unknown_0041 , 0
# real_unknown_0042 , 1
# real_unknown_0043 , 0
# real_unknown_0044 , 0
# real_unknown_0045 , 1
# real_unknown_0046 , 1
# real_unknown_0047 , 0
# real_unknown_0048 , 1
# real_unknown_0049 , 0
# real_unknown_0050 , 1
# real_unknown_0051 , 0
# real_unknown_0052 , 1
# real_unknown_0053 , 1
# real_unknown_0054 , 1
# real_unknown_0055 , 1
# real_unknown_0056 , 0
# real_unknown_0057 , 0
# real_unknown_0058 , 0
# real_unknown_0059 , 1
# real_unknown_0060 , 1
# real_unknown_0061 , 1
# real_unknown_0062 , 1
# real_unknown_0063 , 0
# real_unknown_0064 , 1
# real_unknown_0065 , 0
# real_unknown_0066 , 0
# real_unknown_0067 , 0
# real_unknown_0068 , 0
# real_unknown_0069 , 0
# real_unknown_0070 , 1
# real_unknown_0071 , 0
# real_unknown_0072 , 0
# real_unknown_0073 , 0
# real_unknown_0074 , 1
# real_unknown_0075 , 0
# real_unknown_0076 , 1
# real_unknown_0077 , 0
# real_unknown_0078 , 0
# real_unknown_0079 , 0
# real_unknown_0080 , 1
# real_unknown_0081 , 0
# real_unknown_0082 , 0
# real_unknown_0083 , 0
# real_unknown_0084 , 1
# real_unknown_0085 , 0
# real_unknown_0086 , 0
# real_unknown_0087 , 0
# real_unknown_0088 , 1
# real_unknown_0089 , 1
# real_unknown_0090 , 0
# real_unknown_0091 , 0
# real_unknown_0092 , 0
# real_unknown_0093 , 1
# real_unknown_0094 , 0
# real_unknown_0095 , 0
# real_unknown_0096 , 0
# real_unknown_0097 , 0
# real_unknown_0098 , 0
# real_unknown_0099 , 0
# real_unknown_0100 , 0
# real_unknown_0101 , 1
# real_unknown_0102 , 0
# real_unknown_0103 , 1
# real_unknown_0104 , 0
# real_unknown_0105 , 0
# real_unknown_0106 , 0
# real_unknown_0107 , 1
# real_unknown_0108 , 1
# real_unknown_0109 , 1
# real_unknown_0110 , 1
# real_unknown_0111 , 0
# real_unknown_0112 , 0
# real_unknown_0113 , 0
# real_unknown_0114 , 1
# real_unknown_0115 , 1
# real_unknown_0116 , 0
# real_unknown_0117 , 1
# real_unknown_0118 , 1
# real_unknown_0119 , 0
# real_unknown_0120 , 1
# real_unknown_0121 , 0
# real_unknown_0122 , 0
# real_unknown_0123 , 1
# real_unknown_0124 , 1
# real_unknown_0125 , 0
# real_unknown_0126 , 0
# real_unknown_0127 , 1
# real_unknown_0128 , 0
# real_unknown_0129 , 0
# real_unknown_0130 , 0
# real_unknown_0131 , 0
# real_unknown_0132 , 0
# real_unknown_0133 , 1
# real_unknown_0134 , 0
# real_unknown_0135 , 0
# real_unknown_0136 , 0
# real_unknown_0137 , 1
# real_unknown_0138 , 1
# real_unknown_0139 , 1
# real_unknown_0140 , 0
# real_unknown_0141 , 0
# real_unknown_0142 , 1
# real_unknown_0143 , 1
# real_unknown_0144 , 0
# real_unknown_0145 , 0
# real_unknown_0146 , 1
# real_unknown_0147 , 0
# real_unknown_0148 , 0
# real_unknown_0149 , 0
# real_unknown_0150 , 0
# real_unknown_0151 , 1
# real_unknown_0152 , 1
# real_unknown_0153 , 1
# real_unknown_0154 , 0
# real_unknown_0155 , 0
# real_unknown_0156 , 0
# real_unknown_0157 , 1
# real_unknown_0158 , 0
# real_unknown_0159 , 1
# real_unknown_0160 , 0
# real_unknown_0161 , 0
# real_unknown_0162 , 1
# real_unknown_0163 , 0
# real_unknown_0164 , 1
# real_unknown_0165 , 1
# real_unknown_0166 , 0
# real_unknown_0167 , 0
# real_unknown_0168 , 0
# real_unknown_0169 , 1
# real_unknown_0170 , 0
# real_unknown_0171 , 0
# real_unknown_0172 , 1
# real_unknown_0173 , 1
# real_unknown_0174 , 0
# real_unknown_0175 , 1
# real_unknown_0176 , 0
# real_unknown_0177 , 0
# real_unknown_0178 , 1
# real_unknown_0179 , 0
# real_unknown_0180 , 1
# real_unknown_0181 , 0
# real_unknown_0182 , 0
# real_unknown_0183 , 0
# real_unknown_0184 , 0
# real_unknown_0185 , 0
# real_unknown_0186 , 1
# real_unknown_0187 , 0
# real_unknown_0188 , 1
# real_unknown_0189 , 0
# real_unknown_0190 , 0
# real_unknown_0191 , 0
# real_unknown_0192 , 0
# real_unknown_0193 , 1
# real_unknown_0194 , 0
# real_unknown_0195 , 1
# real_unknown_0196 , 0
# real_unknown_0197 , 0
# real_unknown_0198 , 1
# real_unknown_0199 , 1
# real_unknown_0200 , 0
